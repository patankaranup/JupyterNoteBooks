# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('./tmdb-movies.csv')

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
def get_percent_miss_value_cols(df):
    cols = df.columns
    
    for col in cols:
        percent_missing = df[col].isnull().sum() * 100 / len(df[col])
        print("------------"+col+"------------"+"\n\n"+f"Missing Percentage :{percent_missing}\n\n")
#     if sort == 0:
#         dict1 = sorted(dict1.items(),key=lambda x:x[1],reverse=False)
#         return dict1
#     else:
#         dict1= sorted(dict1.items(),key=lambda x:x[1],reverse=True)

# %%
a = get_percent_miss_value_cols(df)
print(a)
# Out:
# ------------id------------
#
# Missing Percentage :0.0
#
#
# ------------imdb_id------------
#
# Missing Percentage :0.09203018590097552
#
#
# ------------popularity------------
#
# Missing Percentage :0.0
#
#
# ------------budget------------
#
# Missing Percentage :0.0
#
#
# ------------revenue------------
#
# Missing Percentage :0.0
#
#
# ------------original_title------------
#
# Missing Percentage :0.0
#
#
# ------------cast------------
#
# Missing Percentage :0.699429412847414
#
#
# ------------homepage------------
#
# Missing Percentage :72.97993741947359
#
#
# ------------director------------
#
# Missing Percentage :0.4049328179642923
#
#
# ------------tagline------------
#
# Missing Percentage :25.989324498435487
#
#
# ------------keywords------------
#
# Missing Percentage :13.740106755015645
#
#
# ------------overview------------
#
# Missing Percentage :0.03681207436039021
#
#
# ------------runtime------------
#
# Missing Percentage :0.0
#
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
def get_unique_values(dataframe):
    cols = dataframe.columns
    for col in cols:
        print("---------------",col,"---------------")
        print(dataframe[col].unique())
        print("\n\n\n")

# %%
def change_cols_to_datetime(df,cols):
    for col in cols:
        df[col]=pd.to_datetime(df[col])

# %%
get_unique_values(df)
# Out:
# --------------- id ---------------
# [135397  76341 262500 ...  39768  21449  22293]
#
#
#
#
# --------------- imdb_id ---------------
# ['tt0369610' 'tt1392190' 'tt2908446' ... 'tt0060161' 'tt0061177'
#  'tt0060666']
#
#
#
#
# --------------- popularity ---------------
# [32.985763 28.419936 13.112507 ...  0.065141  0.064317  0.035919]
#
#
#
#
# --------------- budget ---------------
# [150000000 110000000 200000000 190000000 135000000 155000000 108000000
#   74000000 175000000 245000000 176000003  15000000  88000000 280000000
#   44000000  48000000 130000000  95000000 160000000  30000000  40000000
#   28000000  68000000  81000000  20000000  61000000         0  49000000
#   29000000  58000000   6000000  50000000  11000000  90000000  75000000
#   25000000  10000000  12000000   4000000  11800000  35000000  55000000
#   60000000 105000000  26000000  70000000 120000001   3500000  65000000
#   50100000 100000000  13000000  99000000   2500000  34000000  80000000
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
date_time_col = ['release_date']

# %%
change_cols_to_datetime(df,date_time_col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...
